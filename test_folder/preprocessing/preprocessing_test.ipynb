# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
# ------------------------------------------------------
# 📂 0. 데이터 로드 & 초기 정리
# ------------------------------------------------------
data_path = 'data/datasets.csv'
data = pd.read_csv(data_path)

# %%
# 불필요한 컬럼 제거
drop_cols = ['EmployeeNumber', 'EmployeeCount', 'Over18', 'StandardHours']
data.drop(columns=drop_cols, inplace=True)

# %%
# 타겟값 변환
data['Attrition'] = data['Attrition'].map({'Yes': 1, 'No': 0})

# %%
# ------------------------------------------------------
# ⚠️ 1. 이상값 및 결측 처리
# ------------------------------------------------------
# 0으로 나누기 방지용 NaN 처리
data['TotalWorkingYears'] = data['TotalWorkingYears'].replace(0, np.nan)
data['YearsAtCompany'] = data['YearsAtCompany'].replace(0, np.nan)

# %%
# ------------------------------------------------------
# 🎯 2. 커리어 관련 파생 변수
# ------------------------------------------------------
data['CareerStartAge'] = data['Age'] - data['TotalWorkingYears']                  # 첫 커리어 시작 나이
data['LoyaltyRatio'] = data['YearsAtCompany'] / data['TotalWorkingYears']        # 충성도 비율
data['PromotionDelay'] = data['YearsAtCompany'] - data['YearsSinceLastPromotion']# 승진까지 소요 기간

# %%
# ------------------------------------------------------
# 🏢 3. 근속 관련 파생 변수
# ------------------------------------------------------
data['CompanyLoyalty'] = data['YearsAtCompany'] / data['TotalWorkingYears']      # 회사 전체 근속 비율
data['RoleStability'] = data['YearsInCurrentRole'] / data['YearsAtCompany']      # 현재 직무 지속 비율
data['ManagerBond'] = data['YearsWithCurrManager'] / data['YearsAtCompany']      # 매니저 유대 비율

# %%
# ------------------------------------------------------
# 🔁 4. 이직/승진 경향
# ------------------------------------------------------
data['JobHopFrequency'] = data['NumCompaniesWorked'] / data['TotalWorkingYears'] # 연평균 이직 횟수
data['RecentlyPromoted'] = (data['YearsSinceLastPromotion'] <= 3).astype(int)     # 최근 3년 내 승진 여부

# %%
# ------------------------------------------------------
# 💰 5. 급여 및 성과 관련 변수
# ------------------------------------------------------
data['IncomePerYear'] = data['MonthlyIncome'] / data['TotalWorkingYears']        # 경력 대비 소득
data['HighPerformerQuit'] = ((data['PerformanceRating'] == 4) & 
                             (data['Attrition'] == 1)).astype(int)                # 고성과 이탈자 여부

# %%
# ------------------------------------------------------
# 🛣️ 6. 스트레스 및 이동 관련 변수
# ------------------------------------------------------
data['LongCommute'] = (data['DistanceFromHome'] > 20).astype(int)                # 장거리 출퇴근 여부
data['OverworkedPoorBalance'] = ((data['OverTime'] == 'Yes') & 
                                 (data['WorkLifeBalance'] <= 2)).astype(int)      # 워라밸 붕괴 여부

# %%
# ------------------------------------------------------
# 😊 7. 종합 만족도
# ------------------------------------------------------
data['OverallSatisfaction'] = (
    data['EnvironmentSatisfaction'] + 
    data['JobSatisfaction'] + 
    data['RelationshipSatisfaction']
) / 3                                                                             # 평균 만족도

# %%
# ------------------------------------------------------
# 🧑‍💼 8. 직급 기반 고위직 구분
# ------------------------------------------------------
manager_roles = ['Manager', 'Research Director']
data['Is_Manager'] = ((data['JobRole'].isin(manager_roles)) & 
                      (data['JobLevel'] >= 3)).astype(int)                        # 고위직 여부

# %%
# ------------------------------------------------------
# 🧹 9. 결측값 정리
# ------------------------------------------------------
data.fillna(0, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. 수치형 컬럼만 추출
numeric_features = data.select_dtypes(include=[np.number])

# 2. 상관계수 계산
corr_matrix = numeric_features.corr()

# 3. Attrition과 상관관계가 높은 순으로 정렬
target_corr = corr_matrix['Attrition'].sort_values(ascending=False)

# 4. 전체 heatmap 시각화
plt.figure(figsize=(14, 12))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title('🔥 Feature Correlation Heatmap')
plt.show()

# 5. Attrition 상관계수 상위 10개만 시각화 (타겟 중심 분석)
top_corr_features = target_corr[1:11]  # 0번째는 Attrition 자기 자신
plt.figure(figsize=(10, 6))
sns.barplot(x=top_corr_features.values, y=top_corr_features.index, palette='RdBu')
plt.title('🎯 Attrition과 상관관계 높은 Top 10 변수')
plt.xlabel('Correlation Coefficient')
plt.tight_layout()
plt.show()

# 5. Attrition 상관계수 상위 10개만 시각화 (타겟 중심 분석)
top_corr_features = target_corr[-10:]  # 0번째는 Attrition 자기 자신
plt.figure(figsize=(10, 6))
sns.barplot(x=top_corr_features.values, y=top_corr_features.index, palette='RdBu')
plt.title('🎯 Attrition과 상관관계 낮은은 Top 10 변수')
plt.xlabel('Correlation Coefficient')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhwoo\AppData\Local\Temp\ipykernel_32448\3813294372.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_corr_features.values, y=top_corr_features.index, palette='RdBu')
# C:\Users\jhwoo\AppData\Local\Temp\ipykernel_32448\3813294372.py:25: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) Malgun Gothic.
#   plt.tight_layout()
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhwoo\AppData\Local\Temp\ipykernel_32448\3813294372.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_corr_features.values, y=top_corr_features.index, palette='RdBu')
# C:\Users\jhwoo\AppData\Local\Temp\ipykernel_32448\3813294372.py:34: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) Malgun Gothic.
#   plt.tight_layout()
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 숫자형 컬럼만 골라서 상관관계 계산
num_cols = data.select_dtypes(include=['int64', 'float64'])
corrs = num_cols.corr()['Attrition'].abs().sort_values()

# 상관계수 낮은 피처 추출
weak_corr = corrs[corrs < 0.01].index.tolist()
print(weak_corr)
# Out:
# ['PerformanceRating', 'HourlyRate']

# %%
drop_these = [
    'HourlyRate', 'MonthlyRate', 'PercentSalaryHike', 
    'LoyaltyRatio', 'CompanyLoyalty', 'Education', 
    'CareerStartAge', 'NumCompaniesWorked', 
    'RelationshipSatisfaction', 'PerformanceRating', 'YearsSinceLastPromotion',
]
data.drop(columns=drop_these, inplace=True)

# %%
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome EducationField  EnvironmentSatisfaction  Gender  \
# 0                 1  Life Sciences                        2  Female
# 1                 8  Life Sciences                        3    Male
# 2                 2          Other                        4    Male
# 3                 3  Life Sciences                        4  Female
# 4                 2        Medical                        1    Male
#
#    JobInvolvement  ...  RoleStability ManagerBond  JobHopFrequency  \
# 0               3  ...       0.666667    0.833333         1.000000
# 1               2  ...       0.700000    0.700000         0.100000
# 2               2  ...       0.000000    0.000000         0.857143
# 3               3  ...       0.875000    0.000000         0.125000
# 4               3  ...       1.000000    1.000000         1.500000
#
#   RecentlyPromoted  IncomePerYear HighPerformerQuit  LongCommute  \
# 0                1     749.125000                 0            0
# 1                1     513.000000                 0            0
# 2                1     298.571429                 0            0
# 3                1     363.625000                 0            0
# 4                1     578.000000                 0            0
#
#    OverworkedPoorBalance  OverallSatisfaction  Is_Manager
# 0                      1             2.333333           0
# 1                      0             3.000000           0
# 2                      0             3.000000           0
# 3                      0             3.333333           0
# 4                      0             2.333333           0
#
# [5 rows x 34 columns]

# %%
# ------------------------------------------------------
# ⚙️ 10. 컬럼 타입 분리
# ------------------------------------------------------
numeric_features = data.select_dtypes(include=['int64', 'float64']).drop(columns=['Attrition']).columns.tolist()
categorical_features = data.select_dtypes(include=['object']).columns.tolist()

# %%
# ------------------------------------------------------
# 🧪 11. 전처리 파이프라인 구성 및 적용
# ------------------------------------------------------
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_features)
    ]
)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# 각 모델에 대해 하이퍼파라미터 그리드 정의
param_grids = {
    'Logistic Regression': {
        'classifier__C': [0.1, 1, 10],  # 정규화 파라미터
        'classifier__solver': ['liblinear', 'saga']  # Solver 선택
    },
    'Random Forest': {
        'classifier__n_estimators': [100, 200],
        'classifier__max_depth': [None, 10, 20],
        'classifier__min_samples_split': [2, 5]
    },
    'Gradient Boosting': {
        'classifier__n_estimators': [100, 200],
        'classifier__learning_rate': [0.01, 0.1, 0.5],
        'classifier__max_depth': [3, 5, 7]
    },
    'Naive Bayes': {
        'classifier__var_smoothing': [1e-9, 1e-8, 1e-7]
    },
    'XGBoost': {
        'classifier__n_estimators': [100, 200],
        'classifier__learning_rate': [0.01, 0.1],
        'classifier__max_depth': [3, 6]
    },
    'LightGBM': {
        'classifier__n_estimators': [100, 200],
        'classifier__learning_rate': [0.01, 0.1],
        'classifier__num_leaves': [31, 50]
    },
    'CatBoost': {
        'classifier__iterations': [100, 200],
        'classifier__learning_rate': [0.01, 0.1],
        'classifier__depth': [3, 5, 7]
    }
}
# 8. 전체 파이프라인 구성
lr_clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=3000))
])

rf_clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier())
])

gb_clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', GradientBoostingClassifier())
])

nb_clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', GaussianNB())
])

xgb_clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', XGBClassifier())
])

lgbm_clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LGBMClassifier())
])

cat_clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', CatBoostClassifier())
])

# %%
from sklearn.model_selection import train_test_split

# 9. 데이터 분리
X = data.drop(columns='Attrition')
y = data['Attrition']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=13)

# %%
# 10. 학습 및 예측
clf_list = [lr_clf, rf_clf, gb_clf, nb_clf, xgb_clf, lgbm_clf, cat_clf]
best_acc = 0.0
best_clf = None
best_model_name = ""
best_params = {}

# 2. GridSearchCV를 사용한 모델 학습 및 하이퍼파라미터 튜닝
for clf, model_name in zip(clf_list, param_grids.keys()):
    grid_search = GridSearchCV(estimator=clf, param_grid=param_grids[model_name], cv=5, scoring='accuracy', verbose=1)
    grid_search.fit(X_train, y_train)
    
    # 가장 좋은 성능의 모델과 파라미터 저장
    if grid_search.best_score_ > best_acc:
        best_acc = grid_search.best_score_
        best_clf = grid_search.best_estimator_
        best_model_name = model_name
        best_params = grid_search.best_params_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [LightGBM] [Info] Number of positive: 152, number of negative: 788
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000721 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1268
# [LightGBM] [Info] Number of data points in the train set: 940, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161702 -> initscore=-1.645618
# [LightGBM] [Info] Start training from score -1.645618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 152, number of negative: 789
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000425 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1270
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161530 -> initscore=-1.646886
# [LightGBM] [Info] Start training from score -1.646886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 152, number of negative: 789
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000393 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1281
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161530 -> initscore=-1.646886
# [LightGBM] [Info] Start training from score -1.646886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 152, number of negative: 789
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000634 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1268
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161530 -> initscore=-1.646886
# [LightGBM] [Info] Start training from score -1.646886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 152, number of negative: 789
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000419 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1269
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161530 -> initscore=-1.646886
# [LightGBM] [Info] Start training from score -1.646886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 152, number of negative: 788
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000408 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1268
# [LightGBM] [Info] Number of data points in the train set: 940, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161702 -> initscore=-1.645618
# [LightGBM] [Info] Start training from score -1.645618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 152, number of negative: 789
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1270
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161530 -> initscore=-1.646886
# [LightGBM] [Info] Start training from score -1.646886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 152, number of negative: 789
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000424 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1281
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161530 -> initscore=-1.646886
# [LightGBM] [Info] Start training from score -1.646886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 152, number of negative: 789
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1268
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161530 -> initscore=-1.646886
# [LightGBM] [Info] Start training from score -1.646886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 152, number of negative: 789
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000479 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1269
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161530 -> initscore=-1.646886
# [LightGBM] [Info] Start training from score -1.646886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 152, number of negative: 788
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000449 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1268
# [LightGBM] [Info] Number of data points in the train set: 940, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161702 -> initscore=-1.645618
# [LightGBM] [Info] Start training from score -1.645618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\jhwoo\anaconda3\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 152, number of negative: 789
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000400 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1270
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 47
# ...
# 192:	learn: 0.0213798	total: 529ms	remaining: 19.2ms
# 193:	learn: 0.0213262	total: 532ms	remaining: 16.5ms
# 194:	learn: 0.0211591	total: 535ms	remaining: 13.7ms
# 195:	learn: 0.0208940	total: 538ms	remaining: 11ms
# 196:	learn: 0.0207591	total: 542ms	remaining: 8.25ms
# 197:	learn: 0.0206827	total: 545ms	remaining: 5.5ms
# 198:	learn: 0.0206668	total: 547ms	remaining: 2.75ms
# 199:	learn: 0.0205043	total: 550ms	remaining: 0us
# 0:	learn: 0.6192461	total: 4.65ms	remaining: 925ms
# 1:	learn: 0.5556338	total: 8.67ms	remaining: 859ms
# 2:	learn: 0.5039742	total: 12.2ms	remaining: 801ms
# 3:	learn: 0.4636140	total: 15.8ms	remaining: 776ms
# 4:	learn: 0.4297484	total: 18.8ms	remaining: 732ms
# 5:	learn: 0.4038005	total: 22ms	remaining: 712ms
# 6:	learn: 0.3799169	total: 25.2ms	remaining: 694ms
# 7:	learn: 0.3598760	total: 27.6ms	remaining: 663ms
# 8:	learn: 0.3428820	total: 32.1ms	remaining: 680ms
# 9:	learn: 0.3325706	total: 36.5ms	remaining: 693ms
# 10:	learn: 0.3187093	total: 40.3ms	remaining: 693ms
# 11:	learn: 0.3028108	total: 43ms	remaining: 674ms
# 12:	learn: 0.2913985	total: 45ms	remaining: 647ms
# 13:	learn: 0.2821472	total: 47.6ms	remaining: 632ms
# 14:	learn: 0.2755191	total: 50.2ms	remaining: 620ms
# 15:	learn: 0.2705182	total: 52.8ms	remaining: 607ms
# 16:	learn: 0.2588787	total: 56.3ms	remaining: 606ms
# 17:	learn: 0.2535003	total: 59.1ms	remaining: 597ms
# 18:	learn: 0.2475997	total: 62.8ms	remaining: 598ms
# 19:	learn: 0.2438204	total: 66.6ms	remaining: 599ms
# 20:	learn: 0.2383416	total: 69.3ms	remaining: 591ms
# 21:	learn: 0.2343788	total: 72.1ms	remaining: 583ms
# 22:	learn: 0.2274477	total: 75.4ms	remaining: 580ms
# 23:	learn: 0.2226415	total: 78.4ms	remaining: 575ms
# 24:	learn: 0.2179293	total: 81.1ms	remaining: 567ms
# 25:	learn: 0.2143198	total: 84.2ms	remaining: 563ms
# 26:	learn: 0.2116479	total: 87.1ms	remaining: 558ms
# 27:	learn: 0.2085775	total: 90.4ms	remaining: 555ms
# 28:	learn: 0.2038906	total: 92.5ms	remaining: 546ms
# 29:	learn: 0.2001679	total: 94.7ms	remaining: 536ms
# 30:	learn: 0.1960074	total: 97.8ms	remaining: 533ms
# 31:	learn: 0.1940719	total: 100ms	remaining: 527ms
# 32:	learn: 0.1883781	total: 104ms	remaining: 524ms
# 33:	learn: 0.1848492	total: 106ms	remaining: 518ms
# 34:	learn: 0.1823235	total: 108ms	remaining: 510ms
# 35:	learn: 0.1778103	total: 110ms	remaining: 503ms
# 36:	learn: 0.1759101	total: 113ms	remaining: 496ms
# 37:	learn: 0.1727305	total: 116ms	remaining: 492ms
# 38:	learn: 0.1681334	total: 119ms	remaining: 490ms
# 39:	learn: 0.1654467	total: 122ms	remaining: 488ms
# 40:	learn: 0.1613554	total: 125ms	remaining: 483ms
# 41:	learn: 0.1587848	total: 128ms	remaining: 481ms
# 42:	learn: 0.1568958	total: 131ms	remaining: 479ms
# 43:	learn: 0.1546226	total: 135ms	remaining: 477ms
# 44:	learn: 0.1521000	total: 137ms	remaining: 472ms
# 45:	learn: 0.1489404	total: 140ms	remaining: 468ms
# 46:	learn: 0.1454998	total: 142ms	remaining: 463ms
# 47:	learn: 0.1434356	total: 145ms	remaining: 459ms
# 48:	learn: 0.1403576	total: 148ms	remaining: 456ms
# 49:	learn: 0.1370279	total: 150ms	remaining: 451ms
# 50:	learn: 0.1348916	total: 153ms	remaining: 447ms
# 51:	learn: 0.1331582	total: 156ms	remaining: 443ms
# 52:	learn: 0.1306701	total: 158ms	remaining: 440ms
# 53:	learn: 0.1289491	total: 162ms	remaining: 438ms
# 54:	learn: 0.1262155	total: 165ms	remaining: 435ms
# 55:	learn: 0.1242548	total: 167ms	remaining: 430ms
# 56:	learn: 0.1224334	total: 169ms	remaining: 425ms
# 57:	learn: 0.1213860	total: 173ms	remaining: 422ms
# 58:	learn: 0.1184426	total: 176ms	remaining: 419ms
# 59:	learn: 0.1162815	total: 178ms	remaining: 416ms
# 60:	learn: 0.1151803	total: 181ms	remaining: 413ms
# 61:	learn: 0.1138187	total: 184ms	remaining: 409ms
# 62:	learn: 0.1119920	total: 186ms	remaining: 405ms
# 63:	learn: 0.1110843	total: 189ms	remaining: 402ms
# 64:	learn: 0.1097376	total: 193ms	remaining: 400ms
# 65:	learn: 0.1074724	total: 196ms	remaining: 397ms
# 66:	learn: 0.1054695	total: 199ms	remaining: 395ms
# 67:	learn: 0.1033369	total: 202ms	remaining: 392ms
# 68:	learn: 0.1027963	total: 204ms	remaining: 388ms
# 69:	learn: 0.1013914	total: 207ms	remaining: 384ms
# 70:	learn: 0.0996606	total: 209ms	remaining: 380ms
# 71:	learn: 0.0978398	total: 212ms	remaining: 377ms
# 72:	learn: 0.0961818	total: 216ms	remaining: 376ms
# 73:	learn: 0.0948507	total: 220ms	remaining: 375ms
# 74:	learn: 0.0938001	total: 223ms	remaining: 372ms
# 75:	learn: 0.0928236	total: 228ms	remaining: 372ms
# 76:	learn: 0.0908718	total: 231ms	remaining: 369ms
# 77:	learn: 0.0894520	total: 234ms	remaining: 365ms
# 78:	learn: 0.0872524	total: 236ms	remaining: 362ms
# 79:	learn: 0.0865722	total: 239ms	remaining: 358ms
# 80:	learn: 0.0851329	total: 241ms	remaining: 355ms
# 81:	learn: 0.0834851	total: 244ms	remaining: 352ms
# 82:	learn: 0.0824958	total: 247ms	remaining: 348ms
# 83:	learn: 0.0810663	total: 249ms	remaining: 344ms
# 84:	learn: 0.0788576	total: 252ms	remaining: 341ms
# 85:	learn: 0.0777916	total: 255ms	remaining: 338ms
# 86:	learn: 0.0762747	total: 258ms	remaining: 335ms
# 87:	learn: 0.0754519	total: 261ms	remaining: 332ms
# 88:	learn: 0.0739861	total: 264ms	remaining: 329ms
# 89:	learn: 0.0729898	total: 267ms	remaining: 326ms
# 90:	learn: 0.0720707	total: 270ms	remaining: 323ms
# 91:	learn: 0.0709696	total: 272ms	remaining: 320ms
# 92:	learn: 0.0698262	total: 275ms	remaining: 316ms
# 93:	learn: 0.0684304	total: 277ms	remaining: 312ms
# 94:	learn: 0.0666500	total: 279ms	remaining: 309ms
# 95:	learn: 0.0651197	total: 282ms	remaining: 306ms
# 96:	learn: 0.0638478	total: 285ms	remaining: 302ms
# 97:	learn: 0.0629933	total: 288ms	remaining: 300ms
# 98:	learn: 0.0612400	total: 291ms	remaining: 297ms
# 99:	learn: 0.0604391	total: 293ms	remaining: 293ms
# 100:	learn: 0.0600260	total: 296ms	remaining: 290ms
# 101:	learn: 0.0596075	total: 299ms	remaining: 287ms
# 102:	learn: 0.0585219	total: 301ms	remaining: 283ms
# 103:	learn: 0.0576677	total: 303ms	remaining: 280ms
# 104:	learn: 0.0570697	total: 306ms	remaining: 277ms
# 105:	learn: 0.0567417	total: 309ms	remaining: 274ms
# 106:	learn: 0.0557799	total: 311ms	remaining: 271ms
# 107:	learn: 0.0548491	total: 314ms	remaining: 267ms
# 108:	learn: 0.0540351	total: 316ms	remaining: 264ms
# 109:	learn: 0.0536878	total: 318ms	remaining: 261ms
# 110:	learn: 0.0526121	total: 321ms	remaining: 257ms
# 111:	learn: 0.0522829	total: 323ms	remaining: 254ms
# 112:	learn: 0.0513134	total: 326ms	remaining: 251ms
# 113:	learn: 0.0501239	total: 328ms	remaining: 247ms
# 114:	learn: 0.0496777	total: 330ms	remaining: 244ms
# 115:	learn: 0.0492260	total: 333ms	remaining: 241ms
# 116:	learn: 0.0489117	total: 336ms	remaining: 239ms
# 117:	learn: 0.0479429	total: 339ms	remaining: 235ms
# 118:	learn: 0.0472359	total: 341ms	remaining: 232ms
# 119:	learn: 0.0464956	total: 344ms	remaining: 229ms
# 120:	learn: 0.0458731	total: 346ms	remaining: 226ms
# 121:	learn: 0.0454009	total: 349ms	remaining: 223ms
# 122:	learn: 0.0448855	total: 351ms	remaining: 220ms
# 123:	learn: 0.0447190	total: 354ms	remaining: 217ms
# 124:	learn: 0.0441673	total: 356ms	remaining: 214ms
# 125:	learn: 0.0430383	total: 359ms	remaining: 211ms
# 126:	learn: 0.0424141	total: 361ms	remaining: 208ms
# 127:	learn: 0.0422732	total: 364ms	remaining: 205ms
# 128:	learn: 0.0419722	total: 366ms	remaining: 202ms
# 129:	learn: 0.0412782	total: 369ms	remaining: 198ms
# 130:	learn: 0.0410721	total: 372ms	remaining: 196ms
# 131:	learn: 0.0404387	total: 374ms	remaining: 193ms
# 132:	learn: 0.0398710	total: 377ms	remaining: 190ms
# 133:	learn: 0.0391416	total: 380ms	remaining: 187ms
# 134:	learn: 0.0389200	total: 382ms	remaining: 184ms
# 135:	learn: 0.0383888	total: 385ms	remaining: 181ms
# 136:	learn: 0.0377833	total: 387ms	remaining: 178ms
# 137:	learn: 0.0374510	total: 390ms	remaining: 175ms
# 138:	learn: 0.0372265	total: 392ms	remaining: 172ms
# 139:	learn: 0.0371993	total: 394ms	remaining: 169ms
# 140:	learn: 0.0365184	total: 397ms	remaining: 166ms
# 141:	learn: 0.0363107	total: 400ms	remaining: 164ms
# 142:	learn: 0.0356554	total: 403ms	remaining: 161ms
# 143:	learn: 0.0352528	total: 405ms	remaining: 158ms
# 144:	learn: 0.0348051	total: 407ms	remaining: 154ms
# 145:	learn: 0.0344318	total: 410ms	remaining: 152ms
# 146:	learn: 0.0340688	total: 412ms	remaining: 149ms
# 147:	learn: 0.0334620	total: 415ms	remaining: 146ms
# 148:	learn: 0.0334414	total: 417ms	remaining: 143ms
# 149:	learn: 0.0327517	total: 420ms	remaining: 140ms
# 150:	learn: 0.0325253	total: 422ms	remaining: 137ms
# 151:	learn: 0.0320941	total: 424ms	remaining: 134ms
# 152:	learn: 0.0319645	total: 428ms	remaining: 131ms
# 153:	learn: 0.0317804	total: 431ms	remaining: 129ms
# 154:	learn: 0.0314798	total: 433ms	remaining: 126ms
# 155:	learn: 0.0310876	total: 436ms	remaining: 123ms
# 156:	learn: 0.0306757	total: 438ms	remaining: 120ms
# 157:	learn: 0.0303176	total: 441ms	remaining: 117ms
# 158:	learn: 0.0301661	total: 445ms	remaining: 115ms
# 159:	learn: 0.0298283	total: 449ms	remaining: 112ms
# 160:	learn: 0.0294762	total: 452ms	remaining: 109ms
# 161:	learn: 0.0293845	total: 454ms	remaining: 107ms
# 162:	learn: 0.0290584	total: 458ms	remaining: 104ms
# 163:	learn: 0.0287872	total: 461ms	remaining: 101ms
# 164:	learn: 0.0284350	total: 464ms	remaining: 98.4ms
# 165:	learn: 0.0282120	total: 467ms	remaining: 95.7ms
# 166:	learn: 0.0279259	total: 470ms	remaining: 92.9ms
# 167:	learn: 0.0277169	total: 473ms	remaining: 90.1ms
# 168:	learn: 0.0273831	total: 502ms	remaining: 92.1ms
# 169:	learn: 0.0273228	total: 505ms	remaining: 89.1ms
# 170:	learn: 0.0270130	total: 509ms	remaining: 86.3ms
# 171:	learn: 0.0269938	total: 512ms	remaining: 83.3ms
# 172:	learn: 0.0266950	total: 515ms	remaining: 80.3ms
# 173:	learn: 0.0264150	total: 532ms	remaining: 79.5ms
# 174:	learn: 0.0260900	total: 535ms	remaining: 76.4ms
# 175:	learn: 0.0258744	total: 538ms	remaining: 73.4ms
# 176:	learn: 0.0254484	total: 540ms	remaining: 70.2ms
# 177:	learn: 0.0252020	total: 543ms	remaining: 67.1ms
# 178:	learn: 0.0250485	total: 546ms	remaining: 64.1ms
# 179:	learn: 0.0249479	total: 550ms	remaining: 61.1ms
# 180:	learn: 0.0245259	total: 553ms	remaining: 58.1ms
# 181:	learn: 0.0242268	total: 556ms	remaining: 55ms
# 182:	learn: 0.0239734	total: 559ms	remaining: 51.9ms
# 183:	learn: 0.0236648	total: 562ms	remaining: 48.9ms
# 184:	learn: 0.0233880	total: 565ms	remaining: 45.8ms
# 185:	learn: 0.0231604	total: 568ms	remaining: 42.8ms
# 186:	learn: 0.0229406	total: 571ms	remaining: 39.7ms
# 187:	learn: 0.0226146	total: 573ms	remaining: 36.6ms
# 188:	learn: 0.0223363	total: 575ms	remaining: 33.5ms
# 189:	learn: 0.0220490	total: 579ms	remaining: 30.5ms
# 190:	learn: 0.0217532	total: 587ms	remaining: 27.7ms
# 191:	learn: 0.0216027	total: 591ms	remaining: 24.6ms
# 192:	learn: 0.0213994	total: 594ms	remaining: 21.6ms
# 193:	learn: 0.0211175	total: 598ms	remaining: 18.5ms
# 194:	learn: 0.0209807	total: 602ms	remaining: 15.4ms
# 195:	learn: 0.0208082	total: 606ms	remaining: 12.4ms
# 196:	learn: 0.0206201	total: 610ms	remaining: 9.29ms
# 197:	learn: 0.0204508	total: 614ms	remaining: 6.2ms
# 198:	learn: 0.0201856	total: 617ms	remaining: 3.1ms
# 199:	learn: 0.0200290	total: 620ms	remaining: 0us
# 0:	learn: 0.6265029	total: 894us	remaining: 88.6ms
# 1:	learn: 0.5787292	total: 1.86ms	remaining: 91.1ms
# 2:	learn: 0.5317736	total: 2.77ms	remaining: 89.5ms
# 3:	learn: 0.4933770	total: 3.98ms	remaining: 95.6ms
# 4:	learn: 0.4675183	total: 4.97ms	remaining: 94.4ms
# 5:	learn: 0.4472879	total: 5.78ms	remaining: 90.6ms
# 6:	learn: 0.4273184	total: 7.11ms	remaining: 94.5ms
# 7:	learn: 0.4104249	total: 8.12ms	remaining: 93.4ms
# 8:	learn: 0.3950507	total: 9.4ms	remaining: 95ms
# 9:	learn: 0.3828723	total: 10.5ms	remaining: 94.4ms
# 10:	learn: 0.3715507	total: 11.5ms	remaining: 92.7ms
# 11:	learn: 0.3639610	total: 12.3ms	remaining: 89.8ms
# 12:	learn: 0.3576949	total: 13ms	remaining: 87ms
# 13:	learn: 0.3537809	total: 14ms	remaining: 86.3ms
# 14:	learn: 0.3472201	total: 15ms	remaining: 84.8ms
# 15:	learn: 0.3424276	total: 16.4ms	remaining: 86.4ms
# 16:	learn: 0.3373077	total: 17.8ms	remaining: 87.1ms
# 17:	learn: 0.3338689	total: 19ms	remaining: 86.5ms
# 18:	learn: 0.3280426	total: 19.8ms	remaining: 84.2ms
# 19:	learn: 0.3249638	total: 20.7ms	remaining: 83ms
# 20:	learn: 0.3221494	total: 21.5ms	remaining: 80.9ms
# 21:	learn: 0.3185360	total: 22.4ms	remaining: 79.5ms
# 22:	learn: 0.3150558	total: 23.3ms	remaining: 78.1ms
# 23:	learn: 0.3133108	total: 24.1ms	remaining: 76.4ms
# 24:	learn: 0.3098772	total: 24.9ms	remaining: 74.8ms
# 25:	learn: 0.3074002	total: 26.4ms	remaining: 75.2ms
# 26:	learn: 0.3051082	total: 27.3ms	remaining: 73.8ms
# 27:	learn: 0.3030448	total: 28ms	remaining: 72ms
# 28:	learn: 0.3022305	total: 29.2ms	remaining: 71.4ms
# 29:	learn: 0.2998043	total: 30.2ms	remaining: 70.5ms
# 30:	learn: 0.2982209	total: 31.1ms	remaining: 69.2ms
# 31:	learn: 0.2962315	total: 32ms	remaining: 68ms
# 32:	learn: 0.2936190	total: 33ms	remaining: 66.9ms
# 33:	learn: 0.2919212	total: 33.9ms	remaining: 65.9ms
# 34:	learn: 0.2895791	total: 35.2ms	remaining: 65.3ms
# 35:	learn: 0.2881145	total: 36.1ms	remaining: 64.2ms
# 36:	learn: 0.2871901	total: 37.1ms	remaining: 63.2ms
# 37:	learn: 0.2857918	total: 37.9ms	remaining: 61.9ms
# 38:	learn: 0.2845601	total: 38.8ms	remaining: 60.6ms
# 39:	learn: 0.2837000	total: 39.8ms	remaining: 59.6ms
# 40:	learn: 0.2821172	total: 40.7ms	remaining: 58.5ms
# 41:	learn: 0.2806134	total: 41.4ms	remaining: 57.2ms
# 42:	learn: 0.2792439	total: 42ms	remaining: 55.7ms
# 43:	learn: 0.2780353	total: 42.7ms	remaining: 54.4ms
# 44:	learn: 0.2766095	total: 43.6ms	remaining: 53.3ms
# 45:	learn: 0.2755291	total: 44.7ms	remaining: 52.5ms
# 46:	learn: 0.2744367	total: 45.6ms	remaining: 51.4ms
# 47:	learn: 0.2732836	total: 46.6ms	remaining: 50.5ms
# 48:	learn: 0.2718512	total: 48ms	remaining: 49.9ms
# 49:	learn: 0.2706164	total: 49ms	remaining: 49ms
# 50:	learn: 0.2699676	total: 49.9ms	remaining: 48ms
# 51:	learn: 0.2683256	total: 51.1ms	remaining: 47.2ms
# 52:	learn: 0.2674712	total: 52ms	remaining: 46.1ms
# 53:	learn: 0.2663793	total: 52.8ms	remaining: 45ms
# 54:	learn: 0.2653243	total: 53.7ms	remaining: 43.9ms
# 55:	learn: 0.2645910	total: 54.5ms	remaining: 42.8ms
# 56:	learn: 0.2632220	total: 55.5ms	remaining: 41.8ms
# 57:	learn: 0.2619950	total: 56.4ms	remaining: 40.8ms
# 58:	learn: 0.2608459	total: 57.7ms	remaining: 40.1ms
# 59:	learn: 0.2589427	total: 58.6ms	remaining: 39.1ms
# 60:	learn: 0.2579632	total: 59.7ms	remaining: 38.2ms
# 61:	learn: 0.2563758	total: 60.6ms	remaining: 37.2ms
# 62:	learn: 0.2553047	total: 61.6ms	remaining: 36.2ms
# 63:	learn: 0.2545037	total: 62.7ms	remaining: 35.2ms
# 64:	learn: 0.2537591	total: 63.7ms	remaining: 34.3ms
# 65:	learn: 0.2525283	total: 64.6ms	remaining: 33.3ms
# 66:	learn: 0.2516060	total: 69.6ms	remaining: 34.3ms
# 67:	learn: 0.2509296	total: 70.7ms	remaining: 33.3ms
# 68:	learn: 0.2488099	total: 71.6ms	remaining: 32.2ms
# 69:	learn: 0.2486601	total: 72.5ms	remaining: 31.1ms
# 70:	learn: 0.2474427	total: 74.3ms	remaining: 30.3ms
# 71:	learn: 0.2465179	total: 75.2ms	remaining: 29.3ms
# 72:	learn: 0.2453758	total: 76ms	remaining: 28.1ms
# 73:	learn: 0.2449677	total: 76.9ms	remaining: 27ms
# 74:	learn: 0.2441221	total: 78.1ms	remaining: 26ms
# 75:	learn: 0.2432341	total: 78.8ms	remaining: 24.9ms
# 76:	learn: 0.2417546	total: 79.6ms	remaining: 23.8ms
# 77:	learn: 0.2408204	total: 80.5ms	remaining: 22.7ms
# 78:	learn: 0.2390297	total: 81.3ms	remaining: 21.6ms
# 79:	learn: 0.2373462	total: 82.2ms	remaining: 20.6ms
# 80:	learn: 0.2361526	total: 83.2ms	remaining: 19.5ms
# 81:	learn: 0.2353377	total: 84.4ms	remaining: 18.5ms
# 82:	learn: 0.2347392	total: 85.8ms	remaining: 17.6ms
# 83:	learn: 0.2336362	total: 86.8ms	remaining: 16.5ms
# 84:	learn: 0.2331061	total: 87.9ms	remaining: 15.5ms
# 85:	learn: 0.2317701	total: 89ms	remaining: 14.5ms
# 86:	learn: 0.2308425	total: 90.1ms	remaining: 13.5ms
# 87:	learn: 0.2298359	total: 91.2ms	remaining: 12.4ms
# 88:	learn: 0.2290543	total: 92.1ms	remaining: 11.4ms
# 89:	learn: 0.2282236	total: 93.1ms	remaining: 10.3ms
# 90:	learn: 0.2273154	total: 94.2ms	remaining: 9.31ms
# 91:	learn: 0.2259781	total: 95.2ms	remaining: 8.27ms
# 92:	learn: 0.2247359	total: 96ms	remaining: 7.23ms
# 93:	learn: 0.2238119	total: 97.2ms	remaining: 6.2ms
# 94:	learn: 0.2227933	total: 98.1ms	remaining: 5.16ms
# 95:	learn: 0.2220439	total: 99.6ms	remaining: 4.15ms
# 96:	learn: 0.2212890	total: 101ms	remaining: 3.11ms
# 97:	learn: 0.2206149	total: 102ms	remaining: 2.08ms
# 98:	learn: 0.2199459	total: 103ms	remaining: 1.04ms
# 99:	learn: 0.2189496	total: 104ms	remaining: 0us

# %%
# 3. 최적의 모델로 예측 및 평가
y_pred = best_clf.predict(X_test)
y_proba = best_clf.predict_proba(X_test)[:, 1]  # Yes일 확률

# 평가 출력
print(f"Best Model: {best_model_name}")
print(f"Best Hyperparameters: {best_params}")
print(classification_report(y_test, y_pred))
print("==============================")
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("==============================")
print(f"ROC AUC: {roc_auc_score(y_test, y_proba):.4f}")
# Out:
# Best Model: Logistic Regression
# Best Hyperparameters: {'classifier__C': 10, 'classifier__solver': 'saga'}
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       247
#            1       0.73      0.47      0.57        47
#
#     accuracy                           0.89       294
#    macro avg       0.82      0.72      0.75       294
# weighted avg       0.88      0.89      0.88       294
#
# ==============================
# Accuracy: 0.8877551020408163
# ==============================
# ROC AUC: 0.8660

# %%
from sklearn.metrics import classification_report, roc_auc_score

# 확률 예측 (Attrition=1일 확률)
y_proba = best_clf.predict_proba(X_test)[:, 1]
def evaluate_threshold(y_true, y_proba, threshold=0.5):
    y_pred = (y_proba >= threshold).astype(int)
    print(f"🔻 Threshold = {threshold:.3f}")
    print(f"accuracy:{accuracy_score(y_test,y_pred)}")
    # print(classification_report(y_true, y_pred, zero_division=0))
    # print(f"ROC-AUC: {roc_auc_score(y_true, y_proba):.4f}")
for t in [0.3, 0.35, 0.4, 0.45, 0.5]:
    evaluate_threshold(y_test, y_proba, threshold=t)
# Out:
# 🔻 Threshold = 0.300
# accuracy:0.8673469387755102
# 🔻 Threshold = 0.350
# accuracy:0.8843537414965986
# 🔻 Threshold = 0.400
# accuracy:0.891156462585034
# 🔻 Threshold = 0.450
# accuracy:0.8945578231292517
# 🔻 Threshold = 0.500
# accuracy:0.8877551020408163
